# %%
from zeek_graphing import *
import pandas as pd

# %%
df = pd.read_csv("reduced_conn.log", sep="\t", skiprows=8, names=zeek_cols["conn"], low_memory=False, na_values=["-"])

df.columns = ['ts',
 'uid',
 'orig_h',
 'orig_p',
 'resp_h',
 'resp_p',
 'proto',
 'service',
 'duration',
 'orig_bytes',
 'resp_bytes',
 'conn_state',
 'local_orig',
 'local_resp',
 'missed_bytes',
 'history',
 'orig_pkts',
 'orig_ip_bytes',
 'resp_pkts',
 'resp_ip_bytes',
 'tunnel_parents']

df.fillna(value = 0, inplace=True)
display(df.sample(5))
# Out:
#                   ts                 uid         orig_h  orig_p  \
# 206175  1.556817e+09  CvmWf331IfRJsxCJ8b  192.168.10.43   20390
# 253495  1.556817e+09  CeumUA3ZSn8fbig8Rk  192.168.10.43   19622
# 115197  1.556791e+09  CqS1nS2gLUcP1UiyPj  192.168.10.43   50971
# 113946  1.556790e+09  CCodrr1IIloJw8OKW4  171.250.24.77   53894
# 168329  1.556817e+09  CUW7Ao4Pzp954bSEA7  192.168.10.43   19622
#
#                  resp_h  resp_p proto service  duration  orig_bytes  \
# 206175    74.142.21.154      22   tcp       0  0.000000         0.0
# 253495  191.229.103.203      23   tcp       0  0.352910         0.0
# 115197    192.168.10.50   10025   tcp       0  0.000000         0.0
# 113946    192.168.61.21      23   tcp       0  3.628433        69.0
# 168329   187.152.168.58      23   tcp       0  0.000000         0.0
#
#         resp_bytes conn_state  local_orig  local_resp  missed_bytes   history  \
# 206175         0.0         S0         0.0         0.0             0         S
# ...

# %%
graph_df = df.head(5000)
zeek_graph(graph_df)
aggregate_session_analysis(graph_df, established_only=True)
# Out:
# <center><h3>Zeek flows from 192.168.10.50</h3></center>
# ## Outbound traffic from 192.168.10.50
# **Traffic to port: 80**
# **No sessions indicative of successful connection on this port.**
# **Traffic to port: 443**
# **No sessions indicative of successful connection on this port.**
# **Traffic to port: 53**
# **Source IP:** 192.168.10.50 ,192.168.10.25 ---> **Destination:** 192.168.2.1
#         **First Seen:** 1556715277.981033 **Last Seen:** 1556716477.862085
#         **Total duration** 18.69 minutes **Data In:** 0.0MB **Data Out:** 0.04MB **number of sessions** --> 96
# **Traffic to port: 23**
# **No sessions indicative of successful connection on this port.**
# **Traffic to port: 123**
# **No sessions indicative of successful connection on this port.**
# **Traffic to port: 445**
# **Source IP:** 192.168.61.20 ,192.168.10.50 ---> **Destination:** 192.168.2.28
#         **First Seen:** 1556714650.744739 **Last Seen:** 1556714701.992097
# ...

# %%
graph_df.to_csv("graphing")
# Out:
#                  ts        orig_p        resp_p     duration    orig_bytes  \
# count  5.000000e+03   5000.000000   5000.000000  5000.000000  5.000000e+03
# mean   1.556716e+09  44944.960600   3698.966600    12.397196  8.376616e+04
# std    8.906398e+02  12701.895748   9651.589631    32.294031  4.170599e+06
# min    1.556714e+09      8.000000      0.000000     0.000000  0.000000e+00
# 25%    1.556716e+09  40721.000000     53.000000     0.000000  0.000000e+00
# 50%    1.556716e+09  40722.000000    443.000000     0.016843  0.000000e+00
# 75%    1.556717e+09  51336.250000   2119.000000     2.998097  7.300000e+01
# max    1.556718e+09  65470.000000  65389.000000   316.286491  2.085512e+08
#
#          resp_bytes  local_orig  local_resp  missed_bytes    orig_pkts  \
# count  5.000000e+03      5000.0      5000.0        5000.0  5000.000000
# mean   3.580855e+03         0.0         0.0           0.0     6.637600
# std    3.473026e+04         0.0         0.0           0.0    19.314836
# ...

# %%
graph_df[["orig_p","resp_p"]].value_counts()
# Out:
# orig_p  resp_p
# 123     123       15
# 23      4447      10
#         2146      10
#         37518      9
# 38018   53         8
# 51196   80         4
# 50984   80         4
# 24891   23         4
# 51034   80         3
# 8       0          3
# 50989   443        3
# 50987   80         3
# 51035   80         3
# 51036   80         3
# 50986   80         3
# 51072   80         3
# 51095   80         3
# 51108   80         3
# 51185   443        3
# 51186   443        3
# 50983   80         3
# 51197   80         3
# 51198   80         3
# 51220   80         3
# 51221   80         3
# 51227   80         3
# 51228   80         3
# 51229   80         3
# 51263   443        3
# 51264   443        3
# 51269   80         3
# 51270   80         3
# 51272   80         3
# 51273   80         3
# 51408   53         3
# 51498   53         3
# 51883   53         3
# 55212   80         3
# 55213   80         3
# 55214   80         3
# 55215   80         3
# 55216   80         3
# ...

# %%
ports = [port for port in df.resp_p]

# %%
Counter(ports)
# Out:
# Counter({23: 90638,
#          22: 59880,
#          53: 30801,
#          80: 28642,
#          443: 9785,
#          2323: 7631,
#          2222: 6202,
#          445: 3386,
#          0: 1107,
#          1: 879,
#          13: 670,
#          3: 272,
#          25: 250,
#          8343: 224,
#          4431: 222,
#          10: 118,
#          123: 112,
#          6881: 97,
#          8080: 77,
#          16113: 74,
#          1052: 74,
#          81: 72,
#          3000: 72,
#          3800: 71,
#          1028: 70,
#          1099: 68,
#          9001: 67,
#          4662: 67,
#          143: 66,
#          6969: 66,
#          843: 64,
#          8081: 62,
#          6667: 62,
#          444: 60,
#          1025: 59,
#          50500: 59,
#          1057: 59,
#          1024: 59,
#          2038: 59,
#          1051: 59,
#          8888: 58,
#          21: 58,
#          1723: 58,
#          139: 58,
#          110: 58,
#          5900: 58,
#          135: 58,
# ...
